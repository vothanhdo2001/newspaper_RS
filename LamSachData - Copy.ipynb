# %%
import pandas as pd
import joblib
from underthesea import word_tokenize
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.decomposition import PCA
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import re
from numpy import hstack
from sklearn.preprocessing import OneHotEncoder
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import hstack
from sqlalchemy import create_engine

# %%
df = pd.read_csv("Dataset_articles_NoID.csv")
df
# Out:
#                                                       URL
# 0       https://laodong.vn/bat-dong-san/thong-tin-ngoc...  \
# 1       https://laodong.vn/bat-dong-san/lo-hong-trong-...
# 2       https://laodong.vn/bat-dong-san/som-hoan-thien...
# 3       https://laodong.vn/bat-dong-san/chi-tiet-ho-so...
# 4       https://laodong.vn/bat-dong-san/khoi-tao-khong...
# ...                                                   ...
# 313315  https://laodong.vn/tlv-canh-doi/ba-lao-mu-nuoi...
# 313316  https://laodong.vn/ho-tro-bao-ve-chu-quyen-bie...
# 313317  https://laodong.vn/giup-do-cac-canh-doi-kho-kh...
# 313318  https://laodong.vn/tlv-canh-doi/hay-giup-do-mo...
# 313319  https://laodong.vn/tlv-nhat-ky/nguoi-dan-ba-qu...
#
#                                                     Title
# 0       Thông tin “Ngọc Trinh mua đất ở Bảo Lộc" chỉ l...  \
# 1       Lỗ hổng trong việc thẩm tra năng lực tài chính...
# 2       Sớm hoàn thiện các dự án nhà ở xã hội để CNLĐ ...
# 3                 Chi tiết hồ sơ hoàn công nhà ở năm 2022
# 4       Khởi tạo không gian sống đẳng cấp, đón sóng đầ...
# ...                                                   ...
# 313315  Bà lão mù nuôi con, cháu bị ảnh hưởng chất độc...
# 313316            Trao 100 triệu đồng cho ngư dân Phú Yên
# 313317  Trao 2 “Mái ấm công đoàn” tới CNVCLĐ khó khăn ...
# 313318              Hãy giúp đỡ một nhà báo cần thay thận
# 313319  “Người đàn bà quỷ ám” ở Quảng Trị đã được nuôi...
#
#                                                   Summary
# 0       Lâm Đồng - Lãnh đạo thành phố Bảo Lộc, Lâm Đồn...  \
# 1       TPHCM - Việc không thể cưỡng chế thuế của hai ...
# 2       Hiện trên địa bàn tỉnh Ninh Bình có 32 khu, cụ...
# 3       Hoàn công nhà ở với ý nghĩa là điều kiện để đư...
# 4       Có rất nhiều lý do khiến những dự án thấp nội ...
# ...                                                   ...
# 313315  Bà Dương Thị Tuyết ở thị trấn Khe Sanh, huyện ...
# 313316  Ngày 25.7, Đại diện Chương trình “Tấm lưới ngh...
# 313317  Ngày 17.7, lãnh đạo Quỹ TLV Lao Động và LĐLĐ t...
# 313318  Nhà báo Trần Đình Chính (tức Trần Hoài Thu) - ...
# 313319  Ngày 2.6, khi nhận được số tiền 500.000 đồng đ...
#
#                                                  Contents
# 0       Những ngày vừa qua, trên trang Facebook chính ...  \
# 1       Theo thông tin từ Cục Thuế TP.HCM, hiện cơ qua...
# 2       CNLĐ mong muốn sớm được tiếp cận với nhà ở xã ...
# 3       Hoàn công nhà ở là một thủ tục hành chính tron...
# 4       Đi dọc đường Lê Văn Lương kéo dài xuống khu Dư...
# ...                                                   ...
# 313315                                                NaN
# 313316                                                NaN
# 313317                                                NaN
# 313318                                                NaN
# 313319                                                NaN
#
#                                       Date               Author(s)
# 0        Thứ sáu, 20/05/2022 08:56 (GMT+7)            Phương Nhiên  \
# 1        Thứ sáu, 20/05/2022 08:10 (GMT+7)                Gia Miêu
# 2        Thứ sáu, 20/05/2022 07:47 (GMT+7)           NGUYỄN TRƯỜNG
# 3        Thứ sáu, 20/05/2022 06:44 (GMT+7)         Kim Nhung (T/H)
# 4        Thứ năm, 19/05/2022 15:30 (GMT+7)            Huyền Nguyễn
# ...                                    ...                     ...
# 313315    Thứ tư, 14/08/2013 06:57 (GMT+7)            Lâm Hưng Thơ
# 313316   Thứ sáu, 26/07/2013 09:03 (GMT+7)               Lưu Phong
# 313317   Thứ năm, 18/07/2013 07:37 (GMT+7)                 Bảo Duy
# 313318   Thứ năm, 20/06/2013 07:28 (GMT+7)  Hoàng Mạnh - Phạm Tùng
# 313319  Chủ nhật, 16/06/2013 19:42 (GMT+7)      Đình Văn - Bảo Duy
#
#              Category                                               Tags
# 0        Bất động sản  ['Lâm Đồng', 'Ngọc Trinh', 'Chiêu trò', 'Giá đ...
# 1        Bất động sản                       ['Thủ Thiêm', 'Đấu giá đất']
# 2        Bất động sản  ['Dự án', 'Nhà ở xã hội', 'Dự án nhà ở xã hội'...
# 3        Bất động sản  ['Giấy phép xây dựng', 'Hồ sơ hoàn công', 'nhà...
# 4        Bất động sản                                   ['An Quý Villa']
# ...               ...                                                ...
# 313315  Tấm Lòng Vàng                                       ['Chất độc']
# 313316  Tin hoạt động                                        ['Phú Yên']
# 313317  Tin hoạt động                  ['Mái ấm Công đoàn', 'Bắc Giang']
# 313318  Tấm Lòng Vàng                                 ['Nhà báo', 'Báo']
# 313319        Quỹ TLV                                      ['Quảng Trị']
#
# [313320 rows x 8 columns]

# %%
#Bỏ cột URL
df = df.drop("URL", axis=1)
#Bỏ cột Tags
df = df.drop("Tags", axis=1)

# %%
#Loại bỏ hàng NULL/NA
df = df.dropna(axis=0, how='any')
#Loại bỏ dòng trùng
df = df.drop_duplicates(keep='last', subset=['Title'])
#Reset index
df = df.reset_index(drop=True)
df
# Out:
#                                                     Title
# 0       Thông tin “Ngọc Trinh mua đất ở Bảo Lộc" chỉ l...  \
# 1       Lỗ hổng trong việc thẩm tra năng lực tài chính...
# 2       Sớm hoàn thiện các dự án nhà ở xã hội để CNLĐ ...
# 3                 Chi tiết hồ sơ hoàn công nhà ở năm 2022
# 4       Khởi tạo không gian sống đẳng cấp, đón sóng đầ...
# ...                                                   ...
# 283381  Quảng Trị: Trao 300 triệu đồng cho người dân b...
# 283382  Trao 100 triệu đồng hỗ trợ CNVCLĐ tỉnh Nghệ An...
# 283383  Quỹ Tấm lòng vàng Lao Động: Trao 4 triệu đồng ...
# 283384  Thêm những tấm lòng thơm thảo hướng về đồng bà...
# 283385      Gần 831 triệu đồng ủng hộ đồng bào Miền Trung
#
#                                                   Summary
# 0       Lâm Đồng - Lãnh đạo thành phố Bảo Lộc, Lâm Đồn...  \
# 1       TPHCM - Việc không thể cưỡng chế thuế của hai ...
# 2       Hiện trên địa bàn tỉnh Ninh Bình có 32 khu, cụ...
# 3       Hoàn công nhà ở với ý nghĩa là điều kiện để đư...
# 4       Có rất nhiều lý do khiến những dự án thấp nội ...
# ...                                                   ...
# 283381  Sáng nay (7.10) tại tỉnh Quảng Trị, đồng chí N...
# 283382  Sáng nay (7.10), tại Nghệ An, Quỹ Tấm lòng vàn...
# 283383  Đại diện Quỹ Tấm lòng Lao Động và LĐLĐ Phú Yên...
# 283384  Tính đến chiều 5.10, Quỹ Tấm lòng vàng (TLV) L...
# 283385  Hưởng ứng lời kêu gọi của Đoàn Chủ tịch TLĐLĐ ...
#
#                                                  Contents
# 0       Những ngày vừa qua, trên trang Facebook chính ...  \
# 1       Theo thông tin từ Cục Thuế TP.HCM, hiện cơ qua...
# 2       CNLĐ mong muốn sớm được tiếp cận với nhà ở xã ...
# 3       Hoàn công nhà ở là một thủ tục hành chính tron...
# 4       Đi dọc đường Lê Văn Lương kéo dài xuống khu Dư...
# ...                                                   ...
# 283381  Đoàn cứu trợ đã trực tiếp về huyện Vĩnh Linh v...
# 283382  Đồng chí Phạm Anh Tuấn cũng cho biết: Chiều qu...
# 283383  Số tiền trên được trích từ nguồn Quỹ Tấm lòng ...
# 283384  Theo đó,  Quỹ TLV Lao Động quyết định hỗ trợ 6...
# 283385  Để giúp CNVC-LĐ và nhân dân 6 tỉnh Miền Trung ...
#
#                                       Date        Author(s)       Category
# 0        Thứ sáu, 20/05/2022 08:56 (GMT+7)     Phương Nhiên   Bất động sản
# 1        Thứ sáu, 20/05/2022 08:10 (GMT+7)         Gia Miêu   Bất động sản
# 2        Thứ sáu, 20/05/2022 07:47 (GMT+7)    NGUYỄN TRƯỜNG   Bất động sản
# 3        Thứ sáu, 20/05/2022 06:44 (GMT+7)  Kim Nhung (T/H)   Bất động sản
# 4        Thứ năm, 19/05/2022 15:30 (GMT+7)     Huyền Nguyễn   Bất động sản
# ...                                    ...              ...            ...
# 283381   Thứ hai, 07/10/2013 12:02 (GMT+7)         Hưng Thơ  Tin hoạt động
# 283382   Thứ hai, 07/10/2013 11:53 (GMT+7)          Bảo Duy  Tin hoạt động
# 283383  Chủ nhật, 06/10/2013 19:33 (GMT+7)          L.Phong  Tin hoạt động
# 283384   Thứ bảy, 05/10/2013 15:51 (GMT+7)          Bảo Duy  Tin hoạt động
# 283385   Thứ sáu, 04/10/2013 19:54 (GMT+7)          K.Chung  Tin hoạt động
#
# [283386 rows x 6 columns]

# %%
#Lọc bớt dữ liệu

# %%
#Đếm số lượng Category
num_unique_categories = df['Category'].nunique()

print(f'Số lượng giá trị duy nhất trong cột Category: {num_unique_categories}')

# Lấy các giá trị duy nhất trong cột Category
unique_categories = df['Category'].unique()

# Hiển thị kết quả
print(f'Các giá trị duy nhất trong cột Category: {unique_categories}')

categories = ['Bất động sản', 'Xã hội', 'Kinh doanh', 'Thời sự', 'Pháp luật', 'Giáo dục', 'Sức khỏe', 'Thể thao', 'Công nghệ', 'Du lịch']
result = df[df['Category'].isin(categories)]

# Nhóm các hàng theo giá trị của cột Category và lấy 1111 dòng đầu tiên cho mỗi nhóm
result = result.groupby('Category').head(1111)
result = result.reset_index(drop=True)
# Hiển thị kết quả
result
# Out:
# Số lượng giá trị duy nhất trong cột Category: 39
# Các giá trị duy nhất trong cột Category: ['Bất động sản' 'Xã hội' 'Lao Động cuối tuần' 'Kinh doanh'
#  'Sự kiện Bình luận' 'Lao Động & Đời sống' 'Thời sự' 'Thế giới' 'Lưu trữ'
#  'Văn hóa - Giải trí' 'Video' 'Diễn đàn' 'Phóng sự' 'Tin bài nổi bật'
#  'Pháp luật' 'Giáo dục' 'Thông tin tiện ích' 'Media' 'Tin địa phương'
#  'Du lịch' 'Thông tin doanh nghiệp' 'Người Việt tử tế' 'Công đoàn'
#  'Sổ tay kinh tế' 'Xe +' 'Thể thao' 'Lao Động Xuân' 'Tin bài xem thêm'
#  'Sức khỏe' 'Tin bài liên quan' 'Gia đình - Hôn nhân'
#  'Tản mạn - Chuyện dọc đường' 'Công nghệ' 'Tin tức việc làm' 'Bạn đọc'
#  'Phóng sự - Điều tra' 'Tấm Lòng Vàng' 'Tin hoạt động' 'Quỹ TLV']
#                                                    Title
# 0      Thông tin “Ngọc Trinh mua đất ở Bảo Lộc" chỉ l...  \
# 1      Lỗ hổng trong việc thẩm tra năng lực tài chính...
# 2      Sớm hoàn thiện các dự án nhà ở xã hội để CNLĐ ...
# 3                Chi tiết hồ sơ hoàn công nhà ở năm 2022
# 4      Khởi tạo không gian sống đẳng cấp, đón sóng đầ...
# ...                                                  ...
# 10005  Đề xuất thay đổi Champions League: “Cái tát và...
# 10006  Tìm hiểu luật chơi golf: Di chuyển vật thể có ...
# 10007  Jeonbuk Hyundai Motors - Sydney FC: Đối đầu đỉ...
# 10008   5 lý do khiến Barcelona thất bại trước Frankfurt
# 10009  Lịch thi đấu chi tiết môn điền kinh tại SEA Ga...
#
#                                                  Summary
# 0      Lâm Đồng - Lãnh đạo thành phố Bảo Lộc, Lâm Đồn...  \
# 1      TPHCM - Việc không thể cưỡng chế thuế của hai ...
# 2      Hiện trên địa bàn tỉnh Ninh Bình có 32 khu, cụ...
# 3      Hoàn công nhà ở với ý nghĩa là điều kiện để đư...
# 4      Có rất nhiều lý do khiến những dự án thấp nội ...
# ...                                                  ...
# 10005  UEFA đang bị cho là lấy ý tưởng của Super Leag...
# 10006  Người chơi golf không được thay đổi các điều k...
# 10007  Jeonbuk Hyundai Motors vs Sydney FC hứa hẹn tạ...
# 10008  Barcelona đang đứng trước một mùa giải trắng t...
# 10009  Bộ môn điền kinh tại SEA Games 31 sẽ diễn ra t...
#
#                                                 Contents
# 0      Những ngày vừa qua, trên trang Facebook chính ...  \
# 1      Theo thông tin từ Cục Thuế TP.HCM, hiện cơ qua...
# 2      CNLĐ mong muốn sớm được tiếp cận với nhà ở xã ...
# 3      Hoàn công nhà ở là một thủ tục hành chính tron...
# 4      Đi dọc đường Lê Văn Lương kéo dài xuống khu Dư...
# ...                                                  ...
# 10005  Nếu như việc các câu lạc bộ lớn quyết định thà...
# 10006  11.3. Cố tình di chuyển vật thể hoặc thay đổi ...
# 10007  Trận đấu giữa Jeonbuk Hyundai Motors vs Sydney...
# 10008  Barcelona chính thức đứt chuỗi 15 trận bất bại...
# 10009  Tại Đại hội Thể thao Đông Nam Á lần thứ 31, đi...
#
#                                     Date        Author(s)      Category
# 0      Thứ sáu, 20/05/2022 08:56 (GMT+7)     Phương Nhiên  Bất động sản
# 1      Thứ sáu, 20/05/2022 08:10 (GMT+7)         Gia Miêu  Bất động sản
# 2      Thứ sáu, 20/05/2022 07:47 (GMT+7)    NGUYỄN TRƯỜNG  Bất động sản
# 3      Thứ sáu, 20/05/2022 06:44 (GMT+7)  Kim Nhung (T/H)  Bất động sản
# 4      Thứ năm, 19/05/2022 15:30 (GMT+7)     Huyền Nguyễn  Bất động sản
# ...                                  ...              ...           ...
# 10005  Thứ sáu, 15/04/2022 17:21 (GMT+7)       TAM NGUYÊN      Thể thao
# 10006  Thứ sáu, 15/04/2022 17:12 (GMT+7)       TAM NGUYÊN      Thể thao
# 10007  Thứ sáu, 15/04/2022 17:00 (GMT+7)      NGUYỄN ĐĂNG      Thể thao
# 10008  Thứ sáu, 15/04/2022 15:39 (GMT+7)    Nguyễn Văn An      Thể thao
# 10009  Thứ sáu, 15/04/2022 15:14 (GMT+7)        AN NGUYÊN      Thể thao
#
# [10010 rows x 6 columns]

# %%
unique_categories = result['Category'].unique()
print(f'Các giá trị duy nhất trong cột Category: {unique_categories}')
# Out:
# Các giá trị duy nhất trong cột Category: ['Bất động sản' 'Xã hội' 'Kinh doanh' 'Thời sự' 'Pháp luật' 'Giáo dục'
#  'Du lịch' 'Thể thao' 'Sức khỏe' 'Công nghệ']

# %%
#Viết hoa cột Author(s)
result.loc[:, "Author(s)"] = result["Author(s)"].str.upper()

# %%
df = result.copy()

# %%
#Chuyển từ tiếng việt sang anh
def convert_vietnamese_date(date_string):
    days = {
        'Thứ hai': 'Monday',
        'Thứ ba': 'Tuesday',
        'Thứ tư': 'Wednesday',
        'Thứ năm': 'Thursday',
        'Thứ sáu': 'Friday',
        'Thứ bảy': 'Saturday',
        'Chủ nhật': 'Sunday'
    }
    for vietnamese_day, english_day in days.items():
        date_string = date_string.replace(vietnamese_day, english_day)
    return date_string

df['Date'] = df['Date'].apply(convert_vietnamese_date)

# %%
def remove_timezone(date_string):
    return date_string.rsplit(' ', 1)[0]

df['Date'] = df['Date'].apply(remove_timezone)
df['Date'] = pd.to_datetime(df['Date'], format='%A, %d/%m/%Y %H:%M')
df['Date'] = df['Date'].dt.strftime('%Y-%m-%d %H:%M')

# %%
df.insert(0, 'id', range(1, 1 + len(df)))
df
# Out:
#           id                                              Title
# 0          1  Thông tin “Ngọc Trinh mua đất ở Bảo Lộc" chỉ l...  \
# 1          2  Lỗ hổng trong việc thẩm tra năng lực tài chính...
# 2          3  Sớm hoàn thiện các dự án nhà ở xã hội để CNLĐ ...
# 3          4            Chi tiết hồ sơ hoàn công nhà ở năm 2022
# 4          5  Khởi tạo không gian sống đẳng cấp, đón sóng đầ...
# ...      ...                                                ...
# 10005  10006  Đề xuất thay đổi Champions League: “Cái tát và...
# 10006  10007  Tìm hiểu luật chơi golf: Di chuyển vật thể có ...
# 10007  10008  Jeonbuk Hyundai Motors - Sydney FC: Đối đầu đỉ...
# 10008  10009   5 lý do khiến Barcelona thất bại trước Frankfurt
# 10009  10010  Lịch thi đấu chi tiết môn điền kinh tại SEA Ga...
#
#                                                  Summary
# 0      Lâm Đồng - Lãnh đạo thành phố Bảo Lộc, Lâm Đồn...  \
# 1      TPHCM - Việc không thể cưỡng chế thuế của hai ...
# 2      Hiện trên địa bàn tỉnh Ninh Bình có 32 khu, cụ...
# 3      Hoàn công nhà ở với ý nghĩa là điều kiện để đư...
# 4      Có rất nhiều lý do khiến những dự án thấp nội ...
# ...                                                  ...
# 10005  UEFA đang bị cho là lấy ý tưởng của Super Leag...
# 10006  Người chơi golf không được thay đổi các điều k...
# 10007  Jeonbuk Hyundai Motors vs Sydney FC hứa hẹn tạ...
# 10008  Barcelona đang đứng trước một mùa giải trắng t...
# 10009  Bộ môn điền kinh tại SEA Games 31 sẽ diễn ra t...
#
#                                                 Contents              Date
# 0      Những ngày vừa qua, trên trang Facebook chính ...  2022-05-20 08:56  \
# 1      Theo thông tin từ Cục Thuế TP.HCM, hiện cơ qua...  2022-05-20 08:10
# 2      CNLĐ mong muốn sớm được tiếp cận với nhà ở xã ...  2022-05-20 07:47
# 3      Hoàn công nhà ở là một thủ tục hành chính tron...  2022-05-20 06:44
# 4      Đi dọc đường Lê Văn Lương kéo dài xuống khu Dư...  2022-05-19 15:30
# ...                                                  ...               ...
# 10005  Nếu như việc các câu lạc bộ lớn quyết định thà...  2022-04-15 17:21
# 10006  11.3. Cố tình di chuyển vật thể hoặc thay đổi ...  2022-04-15 17:12
# 10007  Trận đấu giữa Jeonbuk Hyundai Motors vs Sydney...  2022-04-15 17:00
# 10008  Barcelona chính thức đứt chuỗi 15 trận bất bại...  2022-04-15 15:39
# 10009  Tại Đại hội Thể thao Đông Nam Á lần thứ 31, đi...  2022-04-15 15:14
#
#              Author(s)      Category
# 0         PHƯƠNG NHIÊN  Bất động sản
# 1             GIA MIÊU  Bất động sản
# 2        NGUYỄN TRƯỜNG  Bất động sản
# 3      KIM NHUNG (T/H)  Bất động sản
# 4         HUYỀN NGUYỄN  Bất động sản
# ...                ...           ...
# 10005       TAM NGUYÊN      Thể thao
# 10006       TAM NGUYÊN      Thể thao
# 10007      NGUYỄN ĐĂNG      Thể thao
# 10008    NGUYỄN VĂN AN      Thể thao
# 10009        AN NGUYÊN      Thể thao
#
# [10010 rows x 7 columns]

# %%
# Xuất DataFrame ra tệp CSV
df.to_csv('NewData.csv', index=False)

# %%
# Tạo một từ điển ánh xạ giá trị cũ sang giá trị mới
mapping = {'Bất động sản': 1, 'Xã hội': 2, 'Kinh doanh': 3, 'Thời sự': 4, 'Pháp luật': 5, 'Giáo dục': 6, 'Sức khỏe': 7, 'Thể thao': 8, 'Công nghệ': 9, 'Du lịch': 10}
# Thay đổi giá trị của cột Category
df['Category'] = df['Category'].replace(mapping)

# %%
# Đổi tên các cột của DataFrame để khớp với tên của các cột trong bảng Posts
df = df.rename(columns={'Title': 'title', 'Summary': 'excerpt', 'Contents': 'content', 'Date': 'dateCreate', 'Author(s)': 'author', 'Category': 'category_id'})

# %%
df = df.assign(isEnabled=1, idUser_id=1)
df
# Out:
#           id                                              title
# 0          1  Thông tin “Ngọc Trinh mua đất ở Bảo Lộc" chỉ l...  \
# 1          2  Lỗ hổng trong việc thẩm tra năng lực tài chính...
# 2          3  Sớm hoàn thiện các dự án nhà ở xã hội để CNLĐ ...
# 3          4            Chi tiết hồ sơ hoàn công nhà ở năm 2022
# 4          5  Khởi tạo không gian sống đẳng cấp, đón sóng đầ...
# ...      ...                                                ...
# 10005  10006  Đề xuất thay đổi Champions League: “Cái tát và...
# 10006  10007  Tìm hiểu luật chơi golf: Di chuyển vật thể có ...
# 10007  10008  Jeonbuk Hyundai Motors - Sydney FC: Đối đầu đỉ...
# 10008  10009   5 lý do khiến Barcelona thất bại trước Frankfurt
# 10009  10010  Lịch thi đấu chi tiết môn điền kinh tại SEA Ga...
#
#                                                  excerpt
# 0      Lâm Đồng - Lãnh đạo thành phố Bảo Lộc, Lâm Đồn...  \
# 1      TPHCM - Việc không thể cưỡng chế thuế của hai ...
# 2      Hiện trên địa bàn tỉnh Ninh Bình có 32 khu, cụ...
# 3      Hoàn công nhà ở với ý nghĩa là điều kiện để đư...
# 4      Có rất nhiều lý do khiến những dự án thấp nội ...
# ...                                                  ...
# 10005  UEFA đang bị cho là lấy ý tưởng của Super Leag...
# 10006  Người chơi golf không được thay đổi các điều k...
# 10007  Jeonbuk Hyundai Motors vs Sydney FC hứa hẹn tạ...
# 10008  Barcelona đang đứng trước một mùa giải trắng t...
# 10009  Bộ môn điền kinh tại SEA Games 31 sẽ diễn ra t...
#
#                                                  content        dateCreate
# 0      Những ngày vừa qua, trên trang Facebook chính ...  2022-05-20 08:56  \
# 1      Theo thông tin từ Cục Thuế TP.HCM, hiện cơ qua...  2022-05-20 08:10
# 2      CNLĐ mong muốn sớm được tiếp cận với nhà ở xã ...  2022-05-20 07:47
# 3      Hoàn công nhà ở là một thủ tục hành chính tron...  2022-05-20 06:44
# 4      Đi dọc đường Lê Văn Lương kéo dài xuống khu Dư...  2022-05-19 15:30
# ...                                                  ...               ...
# 10005  Nếu như việc các câu lạc bộ lớn quyết định thà...  2022-04-15 17:21
# 10006  11.3. Cố tình di chuyển vật thể hoặc thay đổi ...  2022-04-15 17:12
# 10007  Trận đấu giữa Jeonbuk Hyundai Motors vs Sydney...  2022-04-15 17:00
# 10008  Barcelona chính thức đứt chuỗi 15 trận bất bại...  2022-04-15 15:39
# 10009  Tại Đại hội Thể thao Đông Nam Á lần thứ 31, đi...  2022-04-15 15:14
#
#                 author  category_id  isEnabled  idUser_id
# 0         PHƯƠNG NHIÊN            1          1          1
# 1             GIA MIÊU            1          1          1
# 2        NGUYỄN TRƯỜNG            1          1          1
# 3      KIM NHUNG (T/H)            1          1          1
# 4         HUYỀN NGUYỄN            1          1          1
# ...                ...          ...        ...        ...
# 10005       TAM NGUYÊN            8          1          1
# 10006       TAM NGUYÊN            8          1          1
# 10007      NGUYỄN ĐĂNG            8          1          1
# 10008    NGUYỄN VĂN AN            8          1          1
# 10009        AN NGUYÊN            8          1          1
#
# [10010 rows x 9 columns]

# %%
# Tạo kết nối đến cơ sở dữ liệu MySQL
engine = create_engine('mysql+mysqlconnector://root:@localhost/TVNews')

# %%
# Chèn dataframe vào bảng Posts trong cơ sở dữ liệu MySQL
start = 0
end = 100
while start < len(df):
    chunk = df.iloc[start:end]
    # insert chunk into mysql database
    chunk.to_sql('api_posts', engine, if_exists='append', index=False)
    start += 100
    end += 100

# %%
#Train

# %%
df = result.copy()
df
# Out:
#                                                    Title
# 0      Thông tin “Ngọc Trinh mua đất ở Bảo Lộc" chỉ l...  \
# 1      Lỗ hổng trong việc thẩm tra năng lực tài chính...
# 2      Sớm hoàn thiện các dự án nhà ở xã hội để CNLĐ ...
# 3                Chi tiết hồ sơ hoàn công nhà ở năm 2022
# 4      Khởi tạo không gian sống đẳng cấp, đón sóng đầ...
# ...                                                  ...
# 10005  Đề xuất thay đổi Champions League: “Cái tát và...
# 10006  Tìm hiểu luật chơi golf: Di chuyển vật thể có ...
# 10007  Jeonbuk Hyundai Motors - Sydney FC: Đối đầu đỉ...
# 10008   5 lý do khiến Barcelona thất bại trước Frankfurt
# 10009  Lịch thi đấu chi tiết môn điền kinh tại SEA Ga...
#
#                                                  Summary
# 0      Lâm Đồng - Lãnh đạo thành phố Bảo Lộc, Lâm Đồn...  \
# 1      TPHCM - Việc không thể cưỡng chế thuế của hai ...
# 2      Hiện trên địa bàn tỉnh Ninh Bình có 32 khu, cụ...
# 3      Hoàn công nhà ở với ý nghĩa là điều kiện để đư...
# 4      Có rất nhiều lý do khiến những dự án thấp nội ...
# ...                                                  ...
# 10005  UEFA đang bị cho là lấy ý tưởng của Super Leag...
# 10006  Người chơi golf không được thay đổi các điều k...
# 10007  Jeonbuk Hyundai Motors vs Sydney FC hứa hẹn tạ...
# 10008  Barcelona đang đứng trước một mùa giải trắng t...
# 10009  Bộ môn điền kinh tại SEA Games 31 sẽ diễn ra t...
#
#                                                 Contents
# 0      Những ngày vừa qua, trên trang Facebook chính ...  \
# 1      Theo thông tin từ Cục Thuế TP.HCM, hiện cơ qua...
# 2      CNLĐ mong muốn sớm được tiếp cận với nhà ở xã ...
# 3      Hoàn công nhà ở là một thủ tục hành chính tron...
# 4      Đi dọc đường Lê Văn Lương kéo dài xuống khu Dư...
# ...                                                  ...
# 10005  Nếu như việc các câu lạc bộ lớn quyết định thà...
# 10006  11.3. Cố tình di chuyển vật thể hoặc thay đổi ...
# 10007  Trận đấu giữa Jeonbuk Hyundai Motors vs Sydney...
# 10008  Barcelona chính thức đứt chuỗi 15 trận bất bại...
# 10009  Tại Đại hội Thể thao Đông Nam Á lần thứ 31, đi...
#
#                                     Date        Author(s)      Category
# 0      Thứ sáu, 20/05/2022 08:56 (GMT+7)     PHƯƠNG NHIÊN  Bất động sản
# 1      Thứ sáu, 20/05/2022 08:10 (GMT+7)         GIA MIÊU  Bất động sản
# 2      Thứ sáu, 20/05/2022 07:47 (GMT+7)    NGUYỄN TRƯỜNG  Bất động sản
# 3      Thứ sáu, 20/05/2022 06:44 (GMT+7)  KIM NHUNG (T/H)  Bất động sản
# 4      Thứ năm, 19/05/2022 15:30 (GMT+7)     HUYỀN NGUYỄN  Bất động sản
# ...                                  ...              ...           ...
# 10005  Thứ sáu, 15/04/2022 17:21 (GMT+7)       TAM NGUYÊN      Thể thao
# 10006  Thứ sáu, 15/04/2022 17:12 (GMT+7)       TAM NGUYÊN      Thể thao
# 10007  Thứ sáu, 15/04/2022 17:00 (GMT+7)      NGUYỄN ĐĂNG      Thể thao
# 10008  Thứ sáu, 15/04/2022 15:39 (GMT+7)    NGUYỄN VĂN AN      Thể thao
# 10009  Thứ sáu, 15/04/2022 15:14 (GMT+7)        AN NGUYÊN      Thể thao
#
# [10010 rows x 6 columns]

# %%
# Bỏ cột id
df = df.drop("id", axis=1)
#Bỏ cột Contents
df = df.drop("Contents", axis=1)
#Bỏ cột Date
df = df.drop("Date", axis=1)
df
# Out:
#                                                    Title
# 0      Thông tin “Ngọc Trinh mua đất ở Bảo Lộc" chỉ l...  \
# 1      Lỗ hổng trong việc thẩm tra năng lực tài chính...
# 2      Sớm hoàn thiện các dự án nhà ở xã hội để CNLĐ ...
# 3                Chi tiết hồ sơ hoàn công nhà ở năm 2022
# 4      Khởi tạo không gian sống đẳng cấp, đón sóng đầ...
# ...                                                  ...
# 10005  Đề xuất thay đổi Champions League: “Cái tát và...
# 10006  Tìm hiểu luật chơi golf: Di chuyển vật thể có ...
# 10007  Jeonbuk Hyundai Motors - Sydney FC: Đối đầu đỉ...
# 10008   5 lý do khiến Barcelona thất bại trước Frankfurt
# 10009  Lịch thi đấu chi tiết môn điền kinh tại SEA Ga...
#
#                                                  Summary        Author(s)
# 0      Lâm Đồng - Lãnh đạo thành phố Bảo Lộc, Lâm Đồn...     PHƯƠNG NHIÊN  \
# 1      TPHCM - Việc không thể cưỡng chế thuế của hai ...         GIA MIÊU
# 2      Hiện trên địa bàn tỉnh Ninh Bình có 32 khu, cụ...    NGUYỄN TRƯỜNG
# 3      Hoàn công nhà ở với ý nghĩa là điều kiện để đư...  KIM NHUNG (T/H)
# 4      Có rất nhiều lý do khiến những dự án thấp nội ...     HUYỀN NGUYỄN
# ...                                                  ...              ...
# 10005  UEFA đang bị cho là lấy ý tưởng của Super Leag...       TAM NGUYÊN
# 10006  Người chơi golf không được thay đổi các điều k...       TAM NGUYÊN
# 10007  Jeonbuk Hyundai Motors vs Sydney FC hứa hẹn tạ...      NGUYỄN ĐĂNG
# 10008  Barcelona đang đứng trước một mùa giải trắng t...    NGUYỄN VĂN AN
# 10009  Bộ môn điền kinh tại SEA Games 31 sẽ diễn ra t...        AN NGUYÊN
#
#            Category
# 0      Bất động sản
# 1      Bất động sản
# 2      Bất động sản
# 3      Bất động sản
# 4      Bất động sản
# ...             ...
# 10005      Thể thao
# 10006      Thể thao
# 10007      Thể thao
# 10008      Thể thao
# 10009      Thể thao
#
# [10010 rows x 4 columns]

# %%
# Tạo một danh sách stopword đơn giản cho tiếng Việt
stop_words = set(["là", "của", "và", "có", "được", "trong", "với", "cho", "đến"])
# Lấy một danh sách stopword cho tiếng Việt từ file
with open("vietnamese-stopwords.txt", "r", encoding="utf-8") as f:
    new_stop_words = set(f.read().splitlines())
    stop_words.update(new_stop_words)

# Định nghĩa hàm chuẩn hóa dữ liệu văn bản
def normalize_text(text):
    # Loại bỏ ký tự đặc biệt và chuyển đổi sang chữ thường
    text = "".join(char for char in text if char.isalnum() or char.isspace()).lower()
    # Tách từ
    words = word_tokenize(text)
    # Loại bỏ stopword
    words = [word for word in words if word not in stop_words]
    # Nối lại các từ đã xử lý
    return " ".join(words)

# Chuẩn hóa dữ liệu văn bản cho cột "Title" và "Summary"
df.loc[:, "Title"] = df["Title"].apply(normalize_text)
df.loc[:, "Summary"] = df["Summary"].apply(normalize_text)

# %%
df_copy = df.copy()
df
# Out:
#                                                    Title
# 0      thông tin ngọc trinh mua đất bảo lộc chiêu trò...  \
# 1      lỗ hổng thẩm tra năng lực tài chính tham gia đ...
# 2                 hoàn thiện dự án nhà ở xã hội cnlđ mua
# 3                          chi tiết hồ sơ hoàn công 2022
# 4      khởi không gian sống đẳng cấp đón sóng đầu tư ...
# ...                                                  ...
# 10005          đề xuất champions league tát má trái uefa
# 10006    luật chơi golf di chuyển vật thể ảnh hưởng bóng
# 10007  jeonbuk hyundai motors sydney fc đối đầu đỉnh cao
# 10008                     5 barcelona thất bại frankfurt
# 10009   lịch thi đấu chi tiết môn điền kinh sea games 31
#
#                                                  Summary        Author(s)
# 0      lâm đồng lãnh đạo thành phố bảo lộc lâm đồng t...     PHƯƠNG NHIÊN  \
# 1      tphcm cưỡng chế thuế hai doanh nghiệp trúng đấ...         GIA MIÊU
# 2      hiện địa bàn tỉnh ninh bình 32 khu cụm công ng...    NGUYỄN TRƯỜNG
# 3      hoàn công ý nghĩa đổi sổ đỏ thể hiện hiện trạn...  KIM NHUNG (T/H)
# 4      dự án nội đô an quý villa giải khát lý tưởng n...     HUYỀN NGUYỄN
# ...                                                  ...              ...
# 10005  uefa ý tưởng super league áp dụng champions le...       TAM NGUYÊN
# 10006                       golf ảnh hưởng đường đi bóng       TAM NGUYÊN
# 10007  jeonbuk hyundai motors vs sydney fc hứa hẹn tr...      NGUYỄN ĐĂNG
# 10008  barcelona đứng mùa giải trắng tay thua frankfu...    NGUYỄN VĂN AN
# 10009  bộ môn điền kinh sea games 31 diễn 145 195 sân...        AN NGUYÊN
#
#            Category
# 0      Bất động sản
# 1      Bất động sản
# 2      Bất động sản
# 3      Bất động sản
# 4      Bất động sản
# ...             ...
# 10005      Thể thao
# 10006      Thể thao
# 10007      Thể thao
# 10008      Thể thao
# 10009      Thể thao
#
# [10010 rows x 4 columns]

# %%
# Khởi tạo vectorizer
vectorizer = TfidfVectorizer()

# Tính toán TF-IDF cho tất cả các thuộc tính
vectorizer.fit(df['Title'] + df['Summary'])
title_tfidf = vectorizer.transform(df['Title'])
summary_tfidf = vectorizer.transform(df['Summary'])

# Kết hợp các ma trận TF-IDF lại với nhau
# (có thể sử dụng các phương pháp khác nhau để kết hợp)
features = hstack([title_tfidf, summary_tfidf])

# %%
# Khởi tạo encoder
encoder_category = OneHotEncoder(handle_unknown='ignore')
encoder_author = OneHotEncoder(handle_unknown='ignore')


# Mã hóa các thuộc tính phân loại
category_encoded = encoder_category.fit_transform(df[['Category']])
author_encoded = encoder_author.fit_transform(df[['Author(s)']])

# Kết hợp các ma trận lại với nhau
features = hstack([features, category_encoded])
features = hstack([features, author_encoded])

# %%
import pickle

# Lưu các biến vào file
with open('variables.pkl', 'wb') as f:
    pickle.dump((vectorizer, encoder_category, encoder_author), f)

# %%
#Lưu file
joblib.dump(features, 'features.joblib')
features
# Out:
# <10010x33912 sparse matrix of type '<class 'numpy.float64'>'
# 	with 355727 stored elements in Compressed Sparse Row format>

# %%
features_new = joblib.load('features.joblib')
features_new
# Out:
# <10010x33912 sparse matrix of type '<class 'numpy.float64'>'
# 	with 355727 stored elements in Compressed Sparse Row format>

# %%
#Features là ma trận đặc trưng đã tính toán ở bước trước

# Khởi tạo mô hình
model = NearestNeighbors()

# Huấn luyện mô hình
model.fit(features)

# Dự đoán mức độ tương tự giữa các bài viết
# (ví dụ: tìm 10 bài viết tương tự nhất với bài viết đầu tiên)
distances, indices = model.kneighbors(features, n_neighbors=10)

# %%
print("Indices:", indices)
print("Distances:", distances)
# Out:
# Indices: [[    0   850   905 ...   371   435   647]
#  [    1   168    15 ...    11   669   608]
#  [    2   231    22 ...   452   111   518]
#  ...
#  [10007  9811  9690 ...  9895  9914  9892]
#  [10008  8944  9849 ...  9163  9968  9915]
#  [10009  9706  9476 ...  9891  9573  9866]]
# Distances: [[0.         2.18978151 2.19560631 ... 2.24071816 2.24195205 2.24727363]
#  [0.         1.52477213 1.52907909 ... 1.65776413 1.66086184 1.68270612]
#  [0.         1.93869929 2.26693577 ... 2.30336053 2.30413922 2.30999498]
#  ...
#  [0.         1.61728007 1.6404974  ... 1.7160157  1.72499178 1.72606848]
#  [0.         1.65622376 1.6715852  ... 1.76567463 1.78597367 1.80044473]
#  [0.         1.69784875 1.72453458 ... 1.79335252 1.79362071 1.79893094]]

# %%
# Lưu mô hình vào file
joblib.dump(model, 'model.pkl')
# Out:
# ['model.pkl']

# %%
split_indices = np.split(indices, indices.shape[1], axis=1)

# Tạo DataFrame từ các mảng con
data = {f'index_{i}': split_indices[i].ravel() for i in range(len(split_indices))}
df = pd.DataFrame(data)
df
# Out:
#        index_0  index_1  index_2  index_3  index_4  index_5  index_6  index_7
# 0            0      850      905      409      698      995      619      371  \
# 1            1      168       15      468      564       78      553       11
# 2            2      231       22      327      527      620       17      452
# 3            3      338     1111      174      457      544      633     1068
# 4            4      789     1096      876     1011        9      979      505
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 10005    10005     9604     9996     9329     9697     9641     9997     9406
# 10006    10006     9663     9898     9902     9783     9073     9035     9072
# 10007    10007     9811     9690     9860     9727     9815     9896     9895
# 10008    10008     8944     9849     9492     8993     9716    10001     9163
# 10009    10009     9706     9476     9471     9269     9339     9718     9891
#
#        index_8  index_9
# 0          435      647
# 1          669      608
# 2          111      518
# 3          306      102
# 4          989      986
# ...        ...      ...
# 10005     9541     9506
# 10006     8996     9696
# 10007     9914     9892
# 10008     9968     9915
# 10009     9573     9866
#
# [10010 rows x 10 columns]

# %%
df = df.add(1)
df
# Out:
#        index_0  index_1  index_2  index_3  index_4  index_5  index_6  index_7
# 0            1      851      906      410      699      996      620      372  \
# 1            2      169       16      469      565       79      554       12
# 2            3      232       23      328      528      621       18      453
# 3            4      339     1112      175      458      545      634     1069
# 4            5      790     1097      877     1012       10      980      506
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 10005    10006     9605     9997     9330     9698     9642     9998     9407
# 10006    10007     9664     9899     9903     9784     9074     9036     9073
# 10007    10008     9812     9691     9861     9728     9816     9897     9896
# 10008    10009     8945     9850     9493     8994     9717    10002     9164
# 10009    10010     9707     9477     9472     9270     9340     9719     9892
#
#        index_8  index_9
# 0          436      648
# 1          670      609
# 2          112      519
# 3          307      103
# 4          990      987
# ...        ...      ...
# 10005     9542     9507
# 10006     8997     9697
# 10007     9915     9893
# 10008     9969     9916
# 10009     9574     9867
#
# [10010 rows x 10 columns]

# %%
#Bỏ cột index_0
df = df.drop("index_0", axis=1)

# %%
df.insert(0, 'index_0', range(1, 1 + len(df)))

# %%
df = df.rename(columns={'index_0': 'idPost_id', 'index_1': 'id1', 'index_2': 'id2', 'index_3': 'id3', 'index_4': 'id4', 'index_5': 'id5', 'index_6': 'id6', 'index_7': 'id7', 'index_8': 'id8', 'index_9': 'id9'})
df
# Out:
#        idPost_id   id1   id2   id3   id4   id5    id6   id7   id8   id9
# 0              1   851   906   410   699   996    620   372   436   648
# 1              2   169    16   469   565    79    554    12   670   609
# 2              3   232    23   328   528   621     18   453   112   519
# 3              4   339  1112   175   458   545    634  1069   307   103
# 4              5   790  1097   877  1012    10    980   506   990   987
# ...          ...   ...   ...   ...   ...   ...    ...   ...   ...   ...
# 10005      10006  9605  9997  9330  9698  9642   9998  9407  9542  9507
# 10006      10007  9664  9899  9903  9784  9074   9036  9073  8997  9697
# 10007      10008  9812  9691  9861  9728  9816   9897  9896  9915  9893
# 10008      10009  8945  9850  9493  8994  9717  10002  9164  9969  9916
# 10009      10010  9707  9477  9472  9270  9340   9719  9892  9574  9867
#
# [10010 rows x 10 columns]

# %%
# Xuất DataFrame ra tệp CSV
df.to_csv('KetQuaDeXuat.csv', index=False, header=False)

# %%
duplicates = df['idPost_id'].duplicated().sum()
duplicates
# Out:
# 0

# %%
# Chèn dataframe vào bảng Posts trong cơ sở dữ liệu MySQL
start = 0
end = 100
while start < len(df):
    chunk = df.iloc[start:end]
    # insert chunk into mysql database
    chunk.to_sql('api_relateds', engine, if_exists='append', index=False)
    start += 100
    end += 100

# %%
#New data

# %%
# Tạo một danh sách stopword đơn giản cho tiếng Việt
stop_words = set(["là", "của", "và", "có", "được", "trong", "với", "cho", "đến"])
# Lấy một danh sách stopword cho tiếng Việt từ file
with open("vietnamese-stopwords.txt", "r", encoding="utf-8") as f:
    new_stop_words = set(f.read().splitlines())
    stop_words.update(new_stop_words)

# %%
# Định nghĩa hàm chuẩn hóa dữ liệu văn bản
def normalize_text(text):
    # Loại bỏ ký tự đặc biệt và chuyển đổi sang chữ thường
    text = "".join(char for char in text if char.isalnum() or char.isspace()).lower()
    # Tách từ
    words = word_tokenize(text)
    # Loại bỏ stopword
    words = [word for word in words if word not in stop_words]
    # Nối lại các từ đã xử lý
    return " ".join(words)

# %%
# Tạo kết nối đến cơ sở dữ liệu MySQL
engine = create_engine('mysql+mysqlconnector://root:@localhost/TVNews')

# %%
df = pd.read_sql_query('SELECT title AS Title, excerpt AS Summary, author AS "Author(s)", c.category AS Category from api_posts as p, api_categorys as c where p.category_id = c.id order by p.id desc limit 1', engine)
df
# Out:
#                                                Title
# 0  Ngoại trưởng Nga: Thế giới sẽ khác khi xung độ...  \
#
#                                              Summary Author(s) Category
# 0  Ngoại trưởng Nga Lavrov nói rằng khi xung đột ...  Huyền Lê  Thời sự

# %%
# Chuẩn hóa dữ liệu văn bản cho cột "Title" và "Summary"
df.loc[:, "Title"] = df["Title"].apply(normalize_text)
df.loc[:, "Summary"] = df["Summary"].apply(normalize_text)
df
# Out:
#                                                Title
# 0  ngoại trưởng nga thế giới xung đột ukraine kết...  \
#
#                                              Summary Author(s) Category
# 0  ngoại trưởng nga lavrov xung đột ukraine kết t...  Huyền Lê  Thời sự

# %%
import pickle
# Tải các biến từ file
with open('variables.pkl', 'rb') as f:
    vectorizer, encoder_category, encoder_author = pickle.load(f)

# %%
category_encoded = encoder_category.transform(df[['Category']])
author_encoded = encoder_author.transform(df[['Author(s)']])
title_tfidf_new = vectorizer.transform(df['Title'])
summary_tfidf_new = vectorizer.transform(df['Summary'])
new_features = hstack([title_tfidf_new, summary_tfidf_new])
new_features = hstack([new_features, category_encoded])
new_features = hstack([new_features, author_encoded])

# %%
new_features
# Out:
# <1x33912 sparse matrix of type '<class 'numpy.float64'>'
# 	with 33 stored elements in Compressed Sparse Row format>

# %%
features = joblib.load('features.joblib')
features
# Out:
# <10011x33912 sparse matrix of type '<class 'numpy.float64'>'
# 	with 355752 stored elements in Compressed Sparse Row format>

# %%
from scipy.sparse import vstack
features = vstack([features, new_features])
features
# Out:
# <10012x33912 sparse matrix of type '<class 'numpy.float64'>'
# 	with 355785 stored elements in Compressed Sparse Row format>

# %%
# Khởi tạo mô hình
model = NearestNeighbors()

# Huấn luyện mô hình
model.fit(features)
# Out:
# NearestNeighbors()

# %%
model.fit(features)
# Out:
# NearestNeighbors()

# %%
# (ví dụ: tìm 10 bài viết tương tự nhất với bài viết đầu tiên)
distances, indices = model.kneighbors(new_features[0], n_neighbors=10)

# %%
print(distances)
# Out:
# [[0.         1.90965789 1.94418125 1.98824228 2.00834194 2.04520681
#   2.05499883 2.0696472  2.0716417  2.0961214 ]]

# %%
print(indices)
# Out:
# [[10011 10010  1465  1763  1882  1856  1926  1858  1396  1988]]

# %%
split_indices = np.split(indices, indices.shape[1], axis=1)

# Tạo DataFrame từ các mảng con
data = {f'index_{i}': split_indices[i].ravel() for i in range(len(split_indices))}
df = pd.DataFrame(data)
df
# Out:
#    index_0  index_1  index_2  index_3  index_4  index_5  index_6  index_7
# 0    10011    10010     1465     1763     1882     1856     1926     1858  \
#
#    index_8  index_9
# 0     1396     1988

# %%
df = df.add(1)

# %%
df = df.rename(columns={'index_0': 'idPost_id', 'index_1': 'id1', 'index_2': 'id2', 'index_3': 'id3', 'index_4': 'id4', 'index_5': 'id5', 'index_6': 'id6', 'index_7': 'id7', 'index_8': 'id8', 'index_9': 'id9'})
df
# Out:
#    idPost_id    id1   id2   id3   id4   id5   id6   id7   id8   id9
# 0      10012  10011  1466  1764  1883  1857  1927  1859  1397  1989

# %%
# Chèn dataframe vào bảng Posts trong cơ sở dữ liệu MySQL
start = 0
end = 100
while start < len(df):
    chunk = df.iloc[start:end]
    # insert chunk into mysql database
    chunk.to_sql('api_relateds', engine, if_exists='append', index=False)
    start += 100
    end += 100

# %%
joblib.dump(model, 'model.pkl')

import pickle

# Lưu các biến vào file
with open('variables.pkl', 'wb') as f:
    pickle.dump((vectorizer, encoder_category, encoder_author), f)
# Lưu file
joblib.dump(features, 'features.joblib')
# Out:
# ['features.joblib']

# %%
##END

# %%
features = joblib.load('features.joblib')
features
# Out:
# <10012x33912 sparse matrix of type '<class 'numpy.float64'>'
# 	with 355785 stored elements in Compressed Sparse Row format>

# %%
from scipy.sparse import vstack
import pickle
import pandas as pd
import joblib
from underthesea import word_tokenize
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.decomposition import PCA
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import re
from numpy import hstack
from sklearn.preprocessing import OneHotEncoder
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import hstack
from sqlalchemy import create_engine


# Tạo một danh sách stopword đơn giản cho tiếng Việt
stop_words = set(["là", "của", "và", "có", "được",
                 "trong", "với", "cho", "đến"])
# Lấy một danh sách stopword cho tiếng Việt từ file
with open("C:\\Users\\votha\\Music\\BE\\Api\\vietnamese-stopwords.txt", "r", encoding="utf-8") as f:
    new_stop_words = set(f.read().splitlines())
    stop_words.update(new_stop_words)
# Định nghĩa hàm chuẩn hóa dữ liệu văn bản


def normalize_text(text):
    # Loại bỏ ký tự đặc biệt và chuyển đổi sang chữ thường
    text = "".join(char for char in text if char.isalnum()
                   or char.isspace()).lower()
    # Tách từ
    words = word_tokenize(text)
    # Loại bỏ stopword
    words = [word for word in words if word not in stop_words]
    # Nối lại các từ đã xử lý
    return " ".join(words)
# Tạo kết nối đến cơ sở dữ liệu MySQL
engine = create_engine('mysql+mysqlconnector://root:@localhost/TVNews')
df = pd.read_sql_query('SELECT title AS Title, excerpt AS Summary, author AS "Author(s)", c.category AS Category from api_posts as p, api_categorys as c where p.category_id = c.id order by p.id desc limit 1', engine)
df
# Out:
#                                          Title
# 0  Nga cảnh báo F-16 'sẽ cháy rụi' tại Ukraine  \
#
#                                              Summary Author(s) Category
# 0  Ông Putin nói F-16 sẽ bị phá hủy nếu tham chiế...    Vũ Anh  Thời sự

# %%
Recommend()

# %%
df
# Out:
#    idPost_id    id1   id2   id3   id4   id5   id6   id7   id8   id9
# 0      10012  10011  1466  1764  1883  1857  1927  1859  1397  1989

# %%
print(indices)
# Out:
# [[10011 10010  1465  1763  1882  1856  1926  1858  1396  1988]]

# %%
def hello():
    print("Hello World!")

# %%
hello()
# Out:
# Hello World!

# %%
from scipy.sparse import vstack
import pickle
import pandas as pd
import joblib
from underthesea import word_tokenize
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.decomposition import PCA
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import re
from numpy import hstack
from sklearn.preprocessing import OneHotEncoder
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import hstack
from sqlalchemy import create_engine


# Tạo một danh sách stopword đơn giản cho tiếng Việt
stop_words = set(["là", "của", "và", "có", "được",
                 "trong", "với", "cho", "đến"])
# Lấy một danh sách stopword cho tiếng Việt từ file
with open("C:\\Users\\votha\\Music\\BE\\Api\\vietnamese-stopwords.txt", "r", encoding="utf-8") as f:
    new_stop_words = set(f.read().splitlines())
    stop_words.update(new_stop_words)
# Định nghĩa hàm chuẩn hóa dữ liệu văn bản


    # Loại bỏ ký tự đặc biệt và chuyển đổi sang chữ thường
    text = "".join(char for char in text if char.isalnum()
                   or char.isspace()).lower()
    # Tách từ
    words = word_tokenize(text)
    # Loại bỏ stopword
    words = [word for word in words if word not in stop_words]
    # Nối lại các từ đã xử lý
    return " ".join(words)


    # Tạo kết nối đến cơ sở dữ liệu MySQL
    engine = create_engine('mysql+mysqlconnector://root:@localhost/TVNews')
    df = pd.read_sql_query(
        'SELECT title AS Title, excerpt AS Summary, author AS "Author(s)", c.category AS Category from api_posts as p, api_categorys as c where p.category_id = c.id order by p.id desc limit 1', engine)
    # Chuẩn hóa dữ liệu văn bản cho cột "Title" và "Summary"
    df.loc[:, "Title"] = df["Title"].apply(normalize_text)
    df.loc[:, "Summary"] = df["Summary"].apply(normalize_text)
    df
    # Tải các biến từ file
    with open('C:\\Users\\votha\\Music\\BE\\Api\\variables.pkl', 'rb') as f:
        vectorizer, encoder_category, encoder_author = pickle.load(f)
    category_encoded = encoder_category.transform(df[['Category']])
    author_encoded = encoder_author.transform(df[['Author(s)']])
    title_tfidf_new = vectorizer.transform(df['Title'])
    summary_tfidf_new = vectorizer.transform(df['Summary'])
    new_features = hstack([title_tfidf_new, summary_tfidf_new])
    new_features = hstack([new_features, category_encoded])
    new_features = hstack([new_features, author_encoded])
    features = joblib.load('C:\\Users\\votha\\Music\\BE\\Api\\features.joblib')
    features = vstack([features, new_features])
    model = NearestNeighbors()
    model.fit(features)
    # (ví dụ: tìm 10 bài viết tương tự nhất với bài viết đầu tiên)
    distances, indices = model.kneighbors(new_features[0], n_neighbors=10)
    split_indices = np.split(indices, indices.shape[1], axis=1)
    # Tạo DataFrame từ các mảng con
    data = {f'index_{i}': split_indices[i].ravel()
            for i in range(len(split_indices))}
    df = pd.DataFrame(data)
    df = df.add(1)
    df = df.rename(columns={'index_0': 'idPost_id', 'index_1': 'id1', 'index_2': 'id2', 'index_3': 'id3',
                            'index_4': 'id4', 'index_5': 'id5', 'index_6': 'id6', 'index_7': 'id7', 'index_8': 'id8', 'index_9': 'id9'})
    # Chèn dataframe vào bảng Posts trong cơ sở dữ liệu MySQL
    start = 0
    end = 100
    while start < len(df):
        chunk = df.iloc[start:end]
        # insert chunk into mysql database
        chunk.to_sql('api_relateds', engine, if_exists='append', index=False)
        start += 100
        end += 100

    # Lưu mô hình vào file
    joblib.dump(model, 'C:\\Users\\votha\\Music\\BE\\Api\\model.pkl')

    import pickle

    # Lưu các biến vào file
    with open('C:\\Users\\votha\\Music\\BE\\Api\\variables.pkl', 'wb') as f:
        pickle.dump((vectorizer, encoder_category, encoder_author), f)

    # Lưu file
    joblib.dump(features, 'C:\\Users\\votha\\Music\\BE\\Api\\features.joblib')
    features
